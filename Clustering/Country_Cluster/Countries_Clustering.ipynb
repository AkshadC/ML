# %% [markdown]
# # A Simple Example of Clustering

# %% [markdown]
# You are given much more country data. Using the same methodology as the one in the lecture, group all the countries in 2 clusters.
#
# Try with other numbers of clusters and see if they match your expectations. Maybe 7 is going to be a cool one!
#
# Plot the data using the <i> c </i> parameter to separate the data by the clusters we defined.
#
# <i> Note: c stands for color <i>

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
seaborn.set()
import warnings
warnings.filterwarnings("ignore")
from sklearn.cluster import KMeans

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load data from the csv file: <i> 'Countries.csv'</i>.

# %%
data = pd.read_csv('Countries-exercise.csv')
data
# Out:
#              name   Longitude   Latitude
# 0           Aruba  -69.982677  12.520880
# 1     Afghanistan   66.004734  33.835231
# 2          Angola   17.537368 -12.293361
# 3        Anguilla  -63.064989  18.223959
# 4         Albania   20.049834  41.142450
# ..            ...         ...        ...
# 236         Samoa -172.164851 -13.753243
# 237         Yemen   47.586762  15.909280
# 238  South Africa   25.083901 -29.000341
# 239        Zambia   27.774759 -13.458242
# 240      Zimbabwe   29.851441 -19.004204
#
# [241 rows x 3 columns]

# %% [markdown]
# ## Plot the data

# %% [markdown]
# Plot the <i>'Longtitude'</i> and <i>'Latitude'</i> columns.

# %%
seaborn.scatterplot(data['Longitude'],data['Latitude'])
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>

# %% [markdown]
# ## Select the features

# %% [markdown]
# Create a copy of that data and remove all parameters apart from <i>Longitude</i> and <i>Latitude</i>.

# %%
X = data.iloc[:,1:3]

# %% [markdown]
# ## Clustering

# %% [markdown]
# Assume there are only two clusters.

# %%
Kmeans = KMeans(7)

# %%
Kmeans.fit(X)
# Out:
# KMeans(n_clusters=7)

# %% [markdown]
# ### Clustering Resutls

# %%
cluster_result = Kmeans.fit_predict(X)

# %%
cluster_result
# Out:
# array([3, 6, 4, 3, 0, 0, 0, 6, 3, 6, 2, 4, 1, 4, 3, 1, 0, 6, 4, 0, 5, 5,
#        6, 0, 6, 3, 3, 0, 3, 0, 3, 3, 3, 3, 3, 1, 6, 4, 5, 0, 3, 6, 5, 5,
#        4, 5, 2, 3, 4, 5, 3, 3, 3, 3, 0, 0, 0, 0, 4, 3, 0, 3, 5, 3, 0, 4,
#        0, 0, 4, 0, 1, 3, 0, 0, 1, 5, 0, 6, 0, 5, 5, 5, 5, 5, 0, 3, 0, 3,
#        1, 3, 1, 4, 3, 0, 3, 0, 1, 0, 6, 1, 4, 0, 6, 6, 0, 0, 0, 3, 0, 0,
#        1, 6, 6, 4, 6, 1, 3, 3, 1, 0, 6, 1, 0, 5, 0, 3, 0, 6, 4, 0, 0, 0,
#        1, 3, 5, 0, 0, 4, 6, 3, 1, 0, 5, 0, 6, 0, 6, 1, 4, 5, 3, 4, 4, 1,
#        4, 1, 5, 1, 5, 3, 2, 0, 0, 6, 1, 1, 6, 6, 3, 2, 3, 1, 1, 1, 0, 3,
#        1, 0, 3, 0, 2, 6, 0, 6, 4, 5, 6, 4, 4, 5, 1, 3, 5, 1, 5, 3, 0, 4,
#        4, 3, 0, 5, 3, 0, 0, 0, 4, 3, 4, 0, 3, 5, 5, 1, 6, 6, 1, 2, 3, 0,
#        0, 1, 4, 4, 0, 3, 3, 6, 0, 3, 3, 3, 3, 1, 1, 2, 2, 6, 4, 4, 4],
#       dtype=int32)

# %% [markdown]
# Did you remember to use the <i> c </i> parameter to separate the data by the clusters we defined?

# %%
df_with_clusters = data.copy()
df_with_clusters['Clusters'] = cluster_result
df_with_clusters
# Out:
#              name   Longitude   Latitude  Clusters
# 0           Aruba  -69.982677  12.520880         3
# 1     Afghanistan   66.004734  33.835231         6
# 2          Angola   17.537368 -12.293361         4
# 3        Anguilla  -63.064989  18.223959         3
# 4         Albania   20.049834  41.142450         0
# ..            ...         ...        ...       ...
# 236         Samoa -172.164851 -13.753243         2
# 237         Yemen   47.586762  15.909280         6
# 238  South Africa   25.083901 -29.000341         4
# 239        Zambia   27.774759 -13.458242         4
# 240      Zimbabwe   29.851441 -19.004204         4
#
# [241 rows x 4 columns]

# %%
plt.scatter(df_with_clusters['Longitude'],df_with_clusters['Latitude'],c=df_with_clusters['Clusters'],cmap='rainbow')
plt.xlim(-180,180)
plt.ylim(-90,90)
plt.show()

# %% [markdown]
# If you haven't, go back and play around with the number of clusters.
#
# Try 3, 7 and 8 and see if the results match your expectations!
